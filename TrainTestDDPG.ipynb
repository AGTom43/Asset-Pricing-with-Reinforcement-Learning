# %% [markdown]
# # DDPG Main

# %%
# %pip install gymnasium
# Out:
# Collecting gymnasium
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1

# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import random
from collections import deque
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch
import numpy as np
import gymnasium
from gymnasium import spaces


# Load data
#C:\Users\rohit\OneDrive\Documents\Asset-Pricing-with-Reinforcement-Learning\XOM_30_minute_6_month_data.csv
from google.colab import drive
drive.mount('/content/drive')

OneDayFiveYears = '/content/drive/MyDrive/UniYear3/RL/XOM_1_day_5_years_price_data.csv'
ThirtyMinSixMonths = '/content/drive/MyDrive/UniYear3/RL/XOM_30_minute_6_month_data.csv'
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(ThirtyMinSixMonths, parse_dates=['Date'])
df.sort_values('Date', inplace=True)

# Normalize
scaler = MinMaxScaler()
df[['Last Price', 'Volume', 'SMAVG (15)']] = scaler.fit_transform(df[['Last Price', 'Volume', 'SMAVG (15)']])

# Split into training and testing sets
train_size = int(len(df) * 0.8)
train_df = df[:train_size]
test_df = df[train_size:]

print(train_df[10:])
# Out:
#                     Date  Last Price    Volume  SMAVG (15)
# 2345 2023-03-06 19:30:00    0.701005  0.088367         NaN
# 2344 2023-03-06 20:00:00    0.685666  0.067463         NaN
# 2343 2023-03-06 20:30:00    0.706041  0.203586         NaN
# 2342 2023-03-07 14:30:00    0.658422  0.154177         NaN
# 2341 2023-03-07 15:00:00    0.650180  0.116092    0.104411
# ...                  ...         ...       ...         ...
# 476  2023-09-29 19:00:00    0.853936  0.068144    0.135628
# 475  2023-09-29 19:30:00    0.876830  0.072069    0.134349
# 474  2023-09-29 20:00:00    0.874999  0.090113    0.137765
# 473  2023-09-29 20:30:00    0.881409  0.306496    0.180971
# 472  2023-10-02 14:30:00    0.794870  0.171930    0.194260
#
# [1874 rows x 4 columns]

# %% [markdown]
# ## Environment

# %%
class DDPGTradingEnv(gymnasium.Env):

  def __init__(self, df):
    super().__init__()

    self.df = df
    self.current_step = 0
    self.total_steps = len(df) - 1

    # Negatives mean quantity to sell, 0 is hold, positives mean buy
    self.action_space = spaces.Box(low=-1, high=1, shape=(1, ), dtype=np.float32)
    # Observation space: normalized last price, normalized shares held, normalized cash balance
    self.observation_space = spaces.Box(low=0, high=1, shape=(3,), dtype=np.float32)

    self.reset()

  def reset(self):
    self.current_step = 0
    self.total_profit = 0
    self.cash_balance = 10000
    self.shares_held = 0
    self.portfolio_value = self.cash_balance

    self.previous_portfolio_value = self.portfolio_value
    # For plotting
    self.portfolio_history = [np.array([self.portfolio_value], dtype=np.float32)]

    self.shares_held_history = [np.array([self.shares_held], dtype=np.float32)]

    return self.get_observation()

  def get_observation(self):
    current_price = self.df['Last Price'].iloc[self.current_step]
    return np.array([float(current_price), float(self.shares_held), float(self.cash_balance)])

  # Action space is one number between -1 and 1.
  def take_action(self, action_value):
    current_price = self.df['Last Price'].iloc[self.current_step]
    if action_value > 0:
      self.buy_stock(action_value, current_price)
    elif action_value < 0:
      self.sell_stock(action_value, current_price)
    # Update the portfolio value
    self.previous_portfolio_value = self.portfolio_value
    self.portfolio_value = self.cash_balance + (self.shares_held * current_price)

  def buy_stock(self, num_stocks, current_price):
    self.cash_balance -= (num_stocks * current_price)
    self.shares_held += num_stocks

  def sell_stock(self, num_stocks, current_price):
    self.cash_balance += (num_stocks * current_price)
    self.shares_held -= num_stocks

  def step(self, action):
    self.current_step += 1
    self.take_action(action)
    reward = self.calculate_reward()
    terminated = (self.current_step >= self.total_steps)
    observation = self.get_observation()
    info = {'current_step': self.current_step, 'portfolio_value': self.portfolio_value}
    self.portfolio_history.append(self.portfolio_value)
    self.shares_held_history.append(self.shares_held)
    #print(self.shares_held)
    return observation, reward, terminated, info

  def render(self, mode='human'):
    if mode == 'human':
      print(f"Step: {self.current_step}, Portfolio Value: {self.portfolio_value}")

  # The reward is the change in portfolio value the next time_step
  def calculate_reward(self):
    reward = self.portfolio_value - self.previous_portfolio_value
    return reward

# %% [markdown]
# ## DDPG Classes

# %%
train_env = DDPGTradingEnv(train_df)
test_env  = DDPGTradingEnv(test_df)

# %% [markdown]
# ## Actor & Critic Class

# %%
# Input: Current state
# Output: Action to be taken
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_size=128):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(state_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_dim)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        x = torch.tanh(self.fc3(x))
        return x

# Input: Current State & Actor's action
# Output: Expected value of state-action pair
class Critic(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_size=128):
        super(Critic, self).__init__()
        self.fc1_state = nn.Linear(state_dim, 64)
        self.fc2_state = nn.Linear(64, 64)
        self.fc2_action = nn.Linear(action_dim, 64)
        self.fc3 = nn.Linear(128, 1)

    def forward(self, state, action):
        x_state = F.relu(self.fc1_state(state))
        x_state = F.relu(self.fc2_state(x_state))

        x_action = F.relu(self.fc2_action(action))

        x = torch.cat((x_state, x_action), dim=0)
        x = F.relu(x)
        x = self.fc3(x)
        return x

# %%
# Because DDPG is an off-policy actor-critic policy-gradient algorithm, this means that the critic
# evaluates the actor, but because they are off-policy, the agents act according to their own
# policy but learn according to the target policy.

class DDPG:
    def __init__(self, df):
        #self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        # Initialise environment:
        self.env = DDPGTradingEnv(df)
        # Pseudocode line 1:
        # Initialize replay memory 𝐷 to capacity 𝑁
        self.N = 1000
        self.replay_memory = []
        # replay_memory = deque(maxlen=N)
        # Initialise minibatch size
        self.minibatch_size = 10
        # Pseudocode line 2 & 3:
        # Initialize actor network 𝜋̂ 1 with parameters 𝒘1 arbitrarily
        # Initialize target actor network 𝜋̂ 2 with parameters 𝒘2=𝒘1
        self.state_dim = 3
        self.action_dim = 1
        self.actor_model = Actor(self.state_dim, self.action_dim)
        self.target_actor_model = Actor(self.state_dim, self.action_dim)
        # Pseudocode line 4 & 5:
        # Initialize critic network 𝑞̂ 1 with parameters 𝜽1 arbitrarily
        # Initialize target critic network 𝑞̂ 2 with parameters 𝜽2=𝜽1
        self.critic_model = Critic(self.state_dim, self.action_dim)
        self.target_critic_model = Critic(self.state_dim, self.action_dim)

        # Initialise random process ϵ for action exploration
        self.epsilon = 0.1
        # Pseudocode line 6: Algorithm parameters: target network learning rate 𝛽>0
        self.beta = 0.01
        # Gamma is the discount factor (importance of future rewards)
        self.gamma = 0.9
        # This is for the gradient descent
        self.lr = 0.01
        # Optimizers
        self.optimizer_critic = optim.Adam(self.critic_model.parameters(), lr=self.lr)
        self.optimizer_actor = optim.Adam(self.actor_model.parameters(), lr=self.lr)

    # policy
    def select_action(self, state):
        # Select action 𝐴←𝜋̂ 1(𝑆,𝒘1)+
        #action = self.actor_model(torch.FloatTensor(state).to(self.device))
        action = self.actor_model(torch.FloatTensor(state))
        # action = action.detach().to('cpu').numpy()
        action = action.detach().numpy()
        # Add exploration noise (optional). Adds dampened value within action space
        action += self.epsilon * np.random.randn(self.action_dim)
        return action

    def store_transition(self, state, action, reward, new_state):
        # Store transition (𝑆,𝐴,𝑅,𝑆′) in 𝐷
        # transition = (state, action, reward, new_state)
        transition = (torch.FloatTensor(state), torch.FloatTensor(action), torch.FloatTensor(reward), torch.FloatTensor(new_state))
        self.replay_memory.append(transition)

    # Allows you to perform updates more frequently & helps with regularisation
    def sample_minibatch(self):
        if len(self.replay_memory) <= self.minibatch_size:
            return self.replay_memory
        else:
            return random.sample(self.replay_memory, self.minibatch_size)

    def update_critic(self, state, action, reward, new_state):
        # Makes sure state and action are on same device
        #state = state.to(self.device)
        #action = action.to(self.device)
        #new_state_tensor = torch.FloatTensor(new_state).to(self.device)
        new_state_tensor = torch.FloatTensor(new_state)

        # 𝜋̂ 2(𝑆′𝑗,𝒘2)
        target_actor_output = self.target_actor_model(new_state_tensor)
        # y is the TD target value (improved Q-value) for the critic (calculated using actor)
        y = reward + self.gamma * self.target_critic_model(new_state_tensor, target_actor_output)

        # Perform gradient descent step ∇𝜽1(𝑦−𝑞̂ 1(𝑆𝑗,𝐴𝑗,𝜽1))2 for critic (critic learning from target critic)
        critic_output = self.critic_model(state, action)
        # critic_loss = F.mse_loss(critic_output, y)
        # y.detach removes tensor
        #critic_loss = nn.MSELoss().to(self.device)(critic_output, y.detach())
        critic_loss = nn.MSELoss()(critic_output, y.detach())
        self.optimizer_critic.zero_grad()
        critic_loss.backward()
        self.optimizer_critic.step()

    def update_actor(self, state):
        # Perform gradient ascent step ∇𝑤1𝐸[𝑞̂ 1(𝑆𝑗,𝜋̂ 1(𝑆𝑗,𝒘1),𝜽1)] for actor (actor learning from critic)
        actor_output = self.actor_model(state)
        actor_loss = -torch.mean(self.critic_model(state, actor_output))
        self.optimizer_actor.zero_grad()
        actor_loss.backward()
        self.optimizer_actor.step()

    def update_target_network_parameters(self):
        # Update target actor network parameters 𝒘2←𝛽𝒘1+(1−𝛽)𝒘2
        for target_param, param in zip(self.target_actor_model.parameters(), self.actor_model.parameters()):
            target_param.data.copy_(self.beta * param.data + (1 - self.beta) * target_param.data)
        # Update target critic network parameters 𝜽2←𝛽𝜽1+(1−𝛽)𝜽2
        for target_param, param in zip(self.target_critic_model.parameters(), self.critic_model.parameters()):
            target_param.data.copy_(self.beta * param.data + (1 - self.beta) * target_param.data)

    def learn(self, state, action, reward, new_state, terminated):
        self.store_transition(state, action, reward, new_state)
        minibatch_sampled_from_D = self.sample_minibatch()
        # For each transition (𝑆𝑗,𝐴𝑗,𝑅𝑗,𝑆′𝑗) in minibatch sampled from 𝐷:
        for transition in minibatch_sampled_from_D:
            # 𝑦←𝑅𝑗+𝛾𝑞̂ 2(𝑆′𝑗,𝜋̂ 2(𝑆′𝑗,𝒘2),𝜽2)
            state, action, reward, new_state = transition
            self.update_critic(state, action, reward, new_state)
            self.update_actor(state)
        self.update_target_network_parameters()

# %%
# Loop for each episode:
num_episodes = 5
DDPG_agent = DDPG(train_df)

for i in range(num_episodes):

    # Initialise S
    state = DDPG_agent.env.reset()

    # Loop for each step of episode (each time step in df)
    terminated = False
    while not terminated:

        action = DDPG_agent.select_action(state)

        # Execute action 𝐴, observe reward 𝑅 and next-state 𝑆′
        new_state, reward, terminated, info = DDPG_agent.env.step(action)

        DDPG_agent.learn(state, action, reward, new_state, terminated)

        # Update state
        state = new_state

# %%
import matplotlib.pyplot as plt

plt.plot(DDPG_agent.env.portfolio_history[1:])
print(DDPG_agent.env.portfolio_history)
plt.title("Portfolio Change Over Time")
plt.xlabel("Steps")
plt.ylabel("Portfolio value")
plt.show()

plt.plot(DDPG_agent.env.shares_held_history)
print(DDPG_agent.env.shares_held_history)
plt.title("Shares Change Over Time")
plt.xlabel("Steps")
plt.ylabel("Portfolio value")
plt.show()
# Out:
# [array([10000.], dtype=float32), array([10000.], dtype=float32), array([9999.989], dtype=float32), array([10000.035], dtype=float32), array([10000.091], dtype=float32), array([10000.134], dtype=float32), array([10000.11], dtype=float32), array([10000.091], dtype=float32), array([10000.072], dtype=float32), array([10000.215], dtype=float32), array([10000.228], dtype=float32), array([10000.075], dtype=float32), array([10000.304], dtype=float32), array([9999.725], dtype=float32), array([9999.617], dtype=float32), array([9999.379], dtype=float32), array([9999.34], dtype=float32), array([9999.485], dtype=float32), array([9999.733], dtype=float32), array([9999.534], dtype=float32), array([9999.098], dtype=float32), array([9998.686], dtype=float32), array([9998.589], dtype=float32), array([9998.442], dtype=float32), array([9998.638], dtype=float32), array([9998.88], dtype=float32), array([9999.566], dtype=float32), array([9998.887], dtype=float32), array([9997.903], dtype=float32), array([9997.696], dtype=float32), array([9996.371], dtype=float32), array([9996.262], dtype=float32), array([9996.545], dtype=float32), array([9995.784], dtype=float32), array([9996.504], dtype=float32), array([9996.705], dtype=float32), array([9995.941], dtype=float32), array([9995.451], dtype=float32), array([9996.928], dtype=float32), array([9999.581], dtype=float32), array([9998.839], dtype=float32), array([9998.857], dtype=float32), array([9999.025], dtype=float32), array([9998.529], dtype=float32), array([9998.354], dtype=float32), array([9997.835], dtype=float32), array([9997.405], dtype=float32), array([9996.737], dtype=float32), array([9997.016], dtype=float32), array([9996.21], dtype=float32), array([9995.407], dtype=float32), array([9994.701], dtype=float32), array([9998.341], dtype=float32), array([9995.67], dtype=float32), array([9995.987], dtype=float32), array([9997.597], dtype=float32), array([9995.097], dtype=float32), array([9995.56], dtype=float32), array([9993.839], dtype=float32), array([9992.198], dtype=float32), array([9990.984], dtype=float32), array([9990.381], dtype=float32), array([9991.551], dtype=float32), array([9990.731], dtype=float32), array([9990.846], dtype=float32), array([9984.225], dtype=float32), array([9984.847], dtype=float32), array([9991.14], dtype=float32), array([9989.585], dtype=float32), array([9989.678], dtype=float32), array([9988.296], dtype=float32), array([9986.959], dtype=float32), array([9986.507], dtype=float32), array([9988.767], dtype=float32), array([9988.866], dtype=float32), array([9988.162], dtype=float32), array([9985.198], dtype=float32), array([9987.062], dtype=float32), array([9993.751], dtype=float32), array([9992.546], dtype=float32), array([9991.915], dtype=float32), array([9994.879], dtype=float32), array([9994.465], dtype=float32), array([9991.117], dtype=float32), array([9990.23], dtype=float32), array([9988.688], dtype=float32), array([9989.112], dtype=float32), array([9987.789], dtype=float32), array([9984.13], dtype=float32), array([9984.468], dtype=float32), array([9987.991], dtype=float32), array([9971.491], dtype=float32), array([9973.118], dtype=float32), array([9970.123], dtype=float32), array([9969.702], dtype=float32), array([9965.234], dtype=float32), array([9962.903], dtype=float32), array([9960.996], dtype=float32), array([9964.477], dtype=float32), array([9963.41], dtype=float32), array([9966.196], dtype=float32), array([9967.46], dtype=float32), array([9965.538], dtype=float32), array([9966.601], dtype=float32), array([9959.425], dtype=float32), array([9951.236], dtype=float32), array([9959.447], dtype=float32), array([9958.164], dtype=float32), array([9957.719], dtype=float32), array([9960.157], dtype=float32), array([9964.742], dtype=float32), array([9964.096], dtype=float32), array([9964.598], dtype=float32), array([9962.478], dtype=float32), array([9963.797], dtype=float32), array([9963.9], dtype=float32), array([9964.005], dtype=float32), array([9963.375], dtype=floa ...
# [array([0.], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135], dtype=float32), array([1885.6135 ...

# %%
test_env = DDPGTradingEnv(test_df)

# Loop for each episode in the testing phase:
num_test_episodes = 1
for episode in range(num_test_episodes):

    # Initialize S
    state = test_env.reset()

    # Loop for each step of the episode
    terminated = False
    while not terminated:

        # Select action using the trained policy (no exploration noise during testing)
        action = DDPG_agent.actor_model(torch.FloatTensor(state)).detach().numpy()

        # Execute action A, observe reward R and next-state S'
        # Here, use the new data from test_df instead of the environment's data
        # Assuming test_df has the same structure as the training data
        new_state, reward, terminated, _ = test_env.step(action)

        # Update state
        state = new_state
    print(test_env.shares_held_history)

plt.plot(test_env.portfolio_history[1:])
print(test_env.portfolio_history)
plt.title("Portfolio Change Over Time")
plt.xlabel("Steps")
plt.ylabel("Portfolio value")
plt.show()

plt.plot(test_env.shares_held_history)
print(test_env.shares_held_history)
plt.title("Shares Change Over Time")
plt.xlabel("Steps")
plt.ylabel("Portfolio value")
plt.show()
# Out:
# [array([0.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471.], dtype=float32), array([471. ...
# [array([10000.], dtype=float32), array([10000.], dtype=float32), array([10000.001], dtype=float32), array([9999.995], dtype=float32), array([10000.026], dtype=float32), array([10000.007], dtype=float32), array([10000.066], dtype=float32), array([10000.01], dtype=float32), array([9999.999], dtype=float32), array([9999.893], dtype=float32), array([10000.103], dtype=float32), array([10000.227], dtype=float32), array([10000.408], dtype=float32), array([10000.282], dtype=float32), array([9999.906], dtype=float